# %% [markdown]
# ## RIQUEZAS-TOTALES

# %% [markdown]
# ### Quiero ver como se dividen las riquezas por los diferentes paises, de los mas ricos a los mas pobres

# %% [markdown]
# dataset --> https://www.kaggle.com/datasets/arpitsinghaiml/average-net-worth-by-country/data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium
import requests

# %% [markdown]
# ## 1 - LIMPIEZA

# %%
data = pd.read_csv("average-net-worth-by-country-2021.csv")

# %%
data.head(20)
# Out:
#           country  AverageNetWorthTotalWealth2021  \
# 0           India                         14225.0
# 1           China                         85107.0
# 2   United States                        145793.0
# 3       Indonesia                          3405.0
# 4        Pakistan                           790.0
# 5         Nigeria                           752.0
# 6          Brazil                          3327.0
# 7      Bangladesh                          1026.0
# 8          Russia                          3789.0
# 9        Ethiopia                           228.0
# 10         Mexico                          4167.0
# 11          Japan                         25692.0
# 12          Egypt                          1405.0
# 13    Philippines                           992.0
# 14       DR Congo                            59.0
# 15        Vietnam                           985.0
# 16           Iran                          2292.0
# 17         Turkey                          1142.0
# 18        Germany                         17489.0
# 19       Thailand                          1341.0
#
#     AverageNetWorthGDPPerAdult2021  AverageNetWorthWealthPerAdult2021  \
# 0                             3465                            15535.0
# 1                            15765                            76639.0
# 2                            91340                           579051.0
# 3                             6472                            18534.0
# 4                             2366                             6237.0
# 5                             4218                             7618.0
# 6                             9993                            21429.0
# 7                             3333                             9490.0
# 8                            15750                            34005.0
# 9                             1679                             3861.0
# 10                           14546                            48138.0
# 11                           45449                           245238.0
# 12                            6626                            23134.0
# 13                            5580                            14502.0
# 14                            1292                             1438.0
# 15                            4186                            14246.0
# 16                           24359                            39093.0
# 17                            9403                            19496.0
# 18                           59423                           256985.0
# 19                            8926                            24638.0
#
#     AverageNetWorthShareOfWorldWealth2021
# 0                                    3.07
# 1                                   18.36
# 2                                   31.45
# 3                                    0.73
# 4                                    0.20
# 5                                    0.20
# 6                                    0.72
# 7                                    0.22
# 8                                    0.80
# 9                                    0.05
# 10                                   0.90
# 11                                   5.54
# 12                                   0.30
# 13                                   0.20
# 14                                   0.01
# 15                                   0.21
# 16                                   0.49
# 17                                   0.30
# 18                                   3.77
# 19                                   0.30

# %%
data = data.rename(columns={
    'country': 'pais',
    'AverageNetWorthTotalWealth2021': 'RiquezaTotal',
    'AverageNetWorthGDPPerAdult2021': 'PIBporAdulto',
    'AverageNetWorthWealthPerAdult2021': 'RiquezaPorAdulto',
    'AverageNetWorthShareOfWorldWealth2021': 'ParticipacionRiquezaMundial'
})

# %%
data.head(20)
# Out:
#              pais  RiquezaTotal  PIBporAdulto  RiquezaPorAdulto  \
# 0           India       14225.0          3465           15535.0
# 1           China       85107.0         15765           76639.0
# 2   United States      145793.0         91340          579051.0
# 3       Indonesia        3405.0          6472           18534.0
# 4        Pakistan         790.0          2366            6237.0
# 5         Nigeria         752.0          4218            7618.0
# 6          Brazil        3327.0          9993           21429.0
# 7      Bangladesh        1026.0          3333            9490.0
# 8          Russia        3789.0         15750           34005.0
# 9        Ethiopia         228.0          1679            3861.0
# 10         Mexico        4167.0         14546           48138.0
# 11          Japan       25692.0         45449          245238.0
# 12          Egypt        1405.0          6626           23134.0
# 13    Philippines         992.0          5580           14502.0
# 14       DR Congo          59.0          1292            1438.0
# 15        Vietnam         985.0          4186           14246.0
# 16           Iran        2292.0         24359           39093.0
# 17         Turkey        1142.0          9403           19496.0
# 18        Germany       17489.0         59423          256985.0
# 19       Thailand        1341.0          8926           24638.0
#
#     ParticipacionRiquezaMundial
# 0                          3.07
# 1                         18.36
# 2                         31.45
# 3                          0.73
# 4                          0.20
# 5                          0.20
# 6                          0.72
# 7                          0.22
# 8                          0.80
# 9                          0.05
# 10                         0.90
# 11                         5.54
# 12                         0.30
# 13                         0.20
# 14                         0.01
# 15                         0.21
# 16                         0.49
# 17                         0.30
# 18                         3.77
# 19                         0.30

# %%
# Porcentaje de nulos
data.isnull().sum() / len(data) * 100
# Out:
# pais                            0.000000
# RiquezaTotal                   21.296296
# PIBporAdulto                    0.000000
# RiquezaPorAdulto               20.833333
# ParticipacionRiquezaMundial    49.074074
# dtype: float64

# %%
data[data.get("RiquezaTotal").isnull()]
# Out:
#                          pais  RiquezaTotal  PIBporAdulto  RiquezaPorAdulto  \
# 29                      Sudan           NaN          2802               NaN
# 42                 Uzbekistan           NaN          3063               NaN
# 49                Ivory Coast           NaN          5296               NaN
# 55                North Korea           NaN           931               NaN
# 67                    Somalia           NaN           280               NaN
# 69                  Guatemala           NaN          8198               NaN
# 80                South Sudan           NaN          2204               NaN
# 84         Dominican Republic           NaN         13374               NaN
# 86                       Cuba           NaN         12849               NaN
# 87                   Honduras           NaN          4643               NaN
# 120                 Palestine           NaN          6465               NaN
# 134               Puerto Rico           NaN         48031               NaN
# 151           North Macedonia           NaN          8624               NaN
# 158                  Eswatini           NaN          7351               NaN
# 161                   Reunion           NaN         38036               NaN
# 165                    Bhutan           NaN          4696               NaN
# 166                     Macau           NaN         52442               NaN
# 172                Cape Verde           NaN          5380               NaN
# 177                Guadeloupe           NaN         33588               NaN
# 178                Martinique           NaN         32857               NaN
# 180                   Mayotte           NaN         22557               NaN
# 181             French Guiana           NaN         25840               NaN
# 182             New Caledonia           NaN         48630               NaN
# 184          French Polynesia           NaN         29500               NaN
# 185     Sao Tome and Principe           NaN          4861            4610.0
# 187                   Curacao           NaN         22146               NaN
# 189                  Kiribati           NaN          3029               NaN
# 192                Micronesia           NaN          5726               NaN
# 197                   Andorra           NaN         52474               NaN
# 198            Cayman Islands           NaN        145583               NaN
# 200                   Bermuda           NaN        189744               NaN
# 201                 Greenland           NaN         83833               NaN
# 202     Saint Kitts and Nevis           NaN         24397               NaN
# 203  Turks and Caicos Islands           NaN         36448               NaN
# 204             Liechtenstein           NaN        252879               NaN
# 205    British Virgin Islands           NaN         76114               NaN
# 206                    Monaco           NaN        242437               NaN
# 207          Marshall Islands           NaN          6693               NaN
# 208                San Marino           NaN         62268               NaN
# 209              Saint Martin           NaN         30547               NaN
# 210                     Palau           NaN         19451               NaN
# 211                  Anguilla           NaN         26510               NaN
# 212              Cook Islands           NaN         26438               NaN
# 213                     Nauru           NaN         23398               NaN
# 214                    Tuvalu           NaN          7780               NaN
# 215                Montserrat           NaN         21123               NaN
#
#      ParticipacionRiquezaMundial
# 29                           NaN
# 42                           NaN
# 49                           NaN
# 55                           NaN
# 67                           NaN
# 69                           NaN
# 80                           NaN
# 84                           NaN
# 86                           NaN
# 87                           NaN
# 120                          NaN
# 134                          NaN
# 151                          NaN
# 158                          NaN
# 161                          NaN
# 165                          NaN
# 166                          NaN
# 172                          NaN
# 177                          NaN
# 178                          NaN
# 180                          NaN
# 181                          NaN
# 182                          NaN
# 184                          NaN
# 185                          NaN
# 187                          NaN
# 189                          NaN
# 192                          NaN
# 197                          NaN
# 198                          NaN
# 200                          NaN
# 201                          NaN
# 202                          NaN
# 203                          NaN
# 204                          NaN
# 205                          NaN
# 206                          NaN
# 207                          NaN
# 208                          NaN
# 209                          NaN
# 210                          NaN
# 211                          NaN
# 212                          NaN
# 213                          NaN
# 214                          NaN
# 215                          NaN

# %%
# Nos quedamos con los valores que no son nulos
data = data[
    data['RiquezaTotal'].notnull()
]

# %%
data.head()
# Out:
#             pais  RiquezaTotal  PIBporAdulto  RiquezaPorAdulto  \
# 0          India       14225.0          3465           15535.0
# 1          China       85107.0         15765           76639.0
# 2  United States      145793.0         91340          579051.0
# 3      Indonesia        3405.0          6472           18534.0
# 4       Pakistan         790.0          2366            6237.0
#
#    ParticipacionRiquezaMundial
# 0                         3.07
# 1                        18.36
# 2                        31.45
# 3                         0.73
# 4                         0.20

# %%
data['pais'].duplicated().any()
# Out:
# False

# %%
data['pais'] = data['pais'].str.lower().str.strip()

# %%
print(data['pais'].tolist())
# Out:
# ['india', 'china', 'united states', 'indonesia', 'pakistan', 'nigeria', 'brazil', 'bangladesh', 'russia', 'ethiopia', 'mexico', 'japan', 'egypt', 'philippines', 'dr congo', 'vietnam', 'iran', 'turkey', 'germany', 'thailand', 'united kingdom', 'tanzania', 'france', 'south africa', 'italy', 'kenya', 'myanmar', 'colombia', 'south korea', 'uganda', 'spain', 'algeria', 'iraq', 'argentina', 'afghanistan', 'yemen', 'canada', 'poland', 'morocco', 'angola', 'ukraine', 'malaysia', 'mozambique', 'ghana', 'peru', 'saudi arabia', 'madagascar', 'nepal', 'cameroon', 'venezuela', 'niger', 'australia', 'syria', 'mali', 'burkina faso', 'taiwan', 'sri lanka', 'malawi', 'zambia', 'kazakhstan', 'chad', 'chile', 'romania', 'senegal', 'netherlands', 'ecuador', 'cambodia', 'zimbabwe', 'guinea', 'benin', 'rwanda', 'burundi', 'bolivia', 'tunisia', 'haiti', 'belgium', 'jordan', 'united arab emirates', 'czech republic', 'sweden', 'tajikistan', 'papua new guinea', 'portugal', 'azerbaijan', 'greece', 'hungary', 'togo', 'israel', 'austria', 'belarus', 'switzerland', 'sierra leone', 'laos', 'turkmenistan', 'hong kong', 'libya', 'kyrgyzstan', 'paraguay', 'nicaragua', 'bulgaria', 'serbia', 'el salvador', 'republic of the congo', 'denmark', 'singapore', 'lebanon', 'finland', 'liberia', 'norway', 'slovakia', 'central african republic', 'oman', 'ireland', 'new zealand', 'mauritania', 'costa rica', 'kuwait', 'panama', 'croatia', 'georgia', 'eritrea', 'mongolia', 'uruguay', 'bosnia and herzegovina', 'qatar', 'moldova', 'namibia', 'armenia', 'lithuania', 'jamaica', 'albania', 'gambia', 'gabon', 'botswana', 'lesotho', 'guinea-bissau', 'slovenia', 'equatorial guinea', 'latvia', 'bahrain', 'trinidad and tobago', 'timor-leste', 'estonia', 'cyprus', 'mauritius', 'djibouti', 'fiji', 'comoros', 'guyana', 'solomon islands', 'luxembourg', 'montenegro', 'suriname', 'malta', 'maldives', 'brunei', 'belize', 'bahamas', 'iceland', 'vanuatu', 'barbados', 'samoa', 'saint lucia', 'seychelles', 'grenada', 'aruba', 'tonga', 'saint vincent and the grenadines', 'antigua and barbuda', 'dominica']

# %%
dicc_pais = {
    'united states': 'united states of america',
    'dr congo': 'democratic republic of the congo',
    'tanzania': 'united republic of tanzania',
    'hong kong sar': 'china',
    'serbia': 'republic of serbia',
    'guinea-bissau': 'guinea bissau',
    'timor-leste': 'east timor',
    'bahamas': 'the bahamas',
    'czechia': 'czech republic',
    'north macedonia': 'macedonia',
    'eswatini': 'swaziland',
    'ivory coast': 'côte d’ivoire',
    'hong kong': 'china',
    'dominica': 'dominican republic'
}

data['pais'] = data['pais'].replace(dicc_pais)

# %% [markdown]
# ## 2 - ANALISIS EXPLORATORIO

# %%
data.head()
# Out:
#                        pais  RiquezaTotal  PIBporAdulto  RiquezaPorAdulto  \
# 0                     india       14225.0          3465           15535.0
# 1                     china       85107.0         15765           76639.0
# 2  united states of america      145793.0         91340          579051.0
# 3                 indonesia        3405.0          6472           18534.0
# 4                  pakistan         790.0          2366            6237.0
#
#    ParticipacionRiquezaMundial
# 0                         3.07
# 1                        18.36
# 2                        31.45
# 3                         0.73
# 4                         0.20

# %%
df_numerico = data.select_dtypes(include=["float64", "int64"])

matriz_correlacion = df_numerico.corr()

plt.figure(figsize=(16, 8)) 
sns.heatmap(matriz_correlacion, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Mapa de correlación entre variables numéricas")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(18, 6))
sns.histplot(data['RiquezaTotal'])
plt.show()

# %%
plt.figure(figsize=(18, 6))
sns.histplot(data['ParticipacionRiquezaMundial'])
plt.show()

# %%
plt.figure(figsize=(18, 6))
sns.histplot(data['PIBporAdulto'])
plt.show()

# %%
plt.figure(figsize=(18, 6))
sns.histplot(data['RiquezaPorAdulto'])
plt.show()

# %%
# Correlación muy fuerte entre RiquezaTotal - ParticipacionRiquezaMundial y PIBporAdulto - RiquezaPorAdulto
# Graficamos cada uno y vemos que es lo mismo.
# Nos quedamos con 'RiquezaTotal' y 'PIBporAdulto' ya que tienen un porcentaje menor de nulos.
data = data[['pais', 'RiquezaTotal', 'PIBporAdulto']]

# %%
data.head()
# Out:
#                        pais  RiquezaTotal  PIBporAdulto
# 0                     india       14225.0          3465
# 1                     china       85107.0         15765
# 2  united states of america      145793.0         91340
# 3                 indonesia        3405.0          6472
# 4                  pakistan         790.0          2366

# %%
# Top 5 países mas ricos
data.nlargest(5, 'RiquezaTotal')
# Out:
#                         pais  RiquezaTotal  PIBporAdulto
# 2   united states of america      145793.0         91340
# 1                      china       85107.0         15765
# 11                     japan       25692.0         45449
# 18                   germany       17489.0         59423
# 20            united kingdom       16261.0         59377

# %%
# Top 5 países mas ricos
top5 = data.nlargest(5, 'RiquezaTotal')

plt.figure(figsize=(10, 5))

sns.barplot(
    data=top5,
    x='pais',
    y='RiquezaTotal'
)

plt.title('Top 5 paises mas ricos', fontsize=14)
plt.xlabel('País')
plt.ylabel('Riqueza Total')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Top 5 países mas pobres
data.nsmallest(5, 'RiquezaTotal')
# Out:
#                                  pais  RiquezaTotal  PIBporAdulto
# 195  saint vincent and the grenadines           1.0         10299
# 196               antigua and barbuda           1.0         20640
# 121          central african republic           2.0          1129
# 146                           lesotho           2.0          2159
# 147                     guinea bissau           2.0          1488

# %%
# Top 5 países mas pobres
bottom5 = data.nsmallest(5, 'RiquezaTotal')

plt.figure(figsize=(10, 5))

sns.barplot(
    data=bottom5,
    x='pais',
    y='RiquezaTotal'
)

plt.title('Top 5 países mas pobres', fontsize=14)
plt.xlabel('País')
plt.ylabel('Riqueza Total')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Gráfico de dispersión con regresión
plt.figure(figsize=(10, 6))
sns.regplot(
    data=data,
    x='PIBporAdulto',
    y='RiquezaTotal',
    fit_reg=False  # Esto quita la línea de regresión
)

# Escala logarítmica en ambos ejes (opcional pero recomendable)
plt.xscale('log')
plt.yscale('log')

# Etiquetas y título
plt.xlabel('PIB por Adulto (log)')
plt.ylabel('Riqueza Total (log)')
plt.title('Relación entre PIB por Adulto y Riqueza Total')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# 1. Cargar GeoJSON de países
url = "https://raw.githubusercontent.com/johan/world.geo.json/master/countries.geo.json"
response = requests.get(url)
geojson_data = response.json()

# 2. Normaliza nombres en el GeoJSON
for feature in geojson_data['features']:
    feature['properties']['name'] = feature['properties']['name'].lower()

# 3. Preparar DataFrame
data['log_riqueza_total'] = np.log10(data['RiquezaTotal'] + 1)

# 4. Crear mapa base con estilo oscuro para contraste y tamaño más pequeño
m = folium.Map(
    location=[20, 0],
    zoom_start=2,
    tiles='cartodbdark_matter'
)

# 5. Estilo tipo "heatmap" por país con líneas visibles
folium.Choropleth(
    geo_data=geojson_data,
    data=data,
    columns=['pais', 'log_riqueza_total'],
    key_on='feature.properties.name',
    fill_color='YlOrRd',  
    fill_opacity=0.9,
    line_opacity=0.7,        
    line_color='white',      
    nan_fill_color='black',
    legend_name='Log₁₀(Riqueza Total + 1)',
    highlight=True,
).add_to(m)

# 6. Tooltip sencillo para país
folium.GeoJson(
    geojson_data,
    style_function=lambda x: {"fillOpacity": 0, "color": "transparent"},
    tooltip=folium.GeoJsonTooltip(
        fields=["name"],
        aliases=["País:"],
        labels=True
    )
).add_to(m)

# %%
# Muestra el mapa en Jupyter
m

# %%
# Paises que no tiene GeoJSON y se quedan fuera:
geo_paises = [feature['properties']['name'] for feature in geojson_data['features']]
geo_paises = [pais.lower().strip() for pais in geo_paises]

no_coinciden = data[~data['pais'].isin(geo_paises)]
print(no_coinciden[['pais']])

# %% [markdown]
# ## CONCLUSIONES

# %% [markdown]
# - A medida que el PIB por adulto aumenta, la riqueza total también suele aumentar.
# - La relación positiva que vemos en el gráfico indica que, en general, los países con un PIB per cápita mayor tienden a tener más riqueza total acumulada.
